# %% [markdown]
# # Huttopia Voice of Customer - Exploration
#
# Notebook d'analyse exploratoire des avis clients.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuration
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Chargement des données

# %%
# TODO Phase 3: Charger les données nettoyées
# df = pd.read_csv('../data/processed/reviews_clean.csv')
# df.head()

# %% [markdown]
# ## 2. Statistiques descriptives

# %%
# TODO: Distribution des notes
# TODO: Répartition par source
# TODO: Évolution temporelle

# %% [markdown]
# ## 3. Analyse thématique

# %%
# TODO Phase 4: Analyser les résultats ML
# TODO: Distribution des thèmes
# TODO: Corrélation thème <-> note

# %% [markdown]
# ## 4. Insights clés

# %%
# TODO Phase 6: Formuler les insights pour le pitch
# Ex: "Le thème propreté concentre 40% des avis négatifs"
